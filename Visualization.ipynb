# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv('Titanic.csv')
df = df.drop('Unnamed: 0',axis=1)
df['Sex'] = df['Sex'].replace({1:'Male',0:'Female'})
df['Embarked'] = df['Embarked'].replace({1:'Queensland',0:'Cherbourg',2:'Southampton'})

df1 = pd.read_csv('Titanic.csv')
df1 = df1.drop('Unnamed: 0',axis=1)
df1['Sex'] = df1['Sex'].replace({1:'Male',0:'Female'})
df1['Embarked'] = df1['Embarked'].replace({1:'Queensland',0:'Cherbourg',2:'Southampton'})

# %%
plt.figure(figsize=(15,10))
plt.subplot(231)
sb.set(style='whitegrid')
splot = sb.barplot(data=df,x='Sex',y='Survived',edgecolor=(0,0,0),linewidth=2,)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', xytext = (0, 11), textcoords = 'offset points')

plt.subplot(232)
sb.set(style='whitegrid')
splot = sb.barplot(data=df,x='Pclass',y='Survived',edgecolor=(0,0,0),linewidth=2)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', xytext = (0, 24), textcoords = 'offset points')

plt.subplot(233)
sb.set(style='whitegrid')
splot = sb.barplot(data=df,x='SibSp',y='Survived',edgecolor=(0,0,0),linewidth=2)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', xytext = (10, 14), textcoords = 'offset points')

plt.subplot(234)
sb.set(style='whitegrid')
splot = sb.barplot(data=df,x='Parch',y='Survived',edgecolor=(0,0,0),linewidth=2)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', xytext = (10, 20), textcoords = 'offset points')

plt.subplot(235)
sb.set(style='whitegrid')
splot = sb.barplot(data=df,x='Embarked',y='Survived',edgecolor=(0,0,0),linewidth=2)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', xytext = (15, 11), textcoords = 'offset points')

plt.savefig('proba.jpg')

# %%
plt.figure(figsize=(15,10))
plt.subplot(231)
sb.set(style='whitegrid')
splot = sb.countplot(df['Sex'],edgecolor=(0,0,0),linewidth=2)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', xytext = (0, 10), textcoords = 'offset points')

plt.subplot(232)
sb.set(style='whitegrid')
splot = sb.countplot(df['Pclass'],edgecolor=(0,0,0),linewidth=2)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', xytext = (0, 10), textcoords = 'offset points')

plt.subplot(233)
sb.set(style='whitegrid')
splot = sb.countplot(df['SibSp'],edgecolor=(0,0,0),linewidth=2)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', xytext = (0, 10), textcoords = 'offset points')

plt.subplot(234)
sb.set(style='whitegrid')
splot = sb.countplot(df['Parch'],edgecolor=(0,0,0),linewidth=2)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', xytext = (0, 10), textcoords = 'offset points')

plt.subplot(235)
sb.set(style='whitegrid')
splot = sb.countplot(df['Embarked'],edgecolor=(0,0,0),linewidth=2)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', xytext = (0, 10), textcoords = 'offset points')

plt.savefig('count.jpg')

# %%
df0 = df

# %%
df0['Survived'] = df0['Survived'][df0['Survived']==0]
df0.dropna(inplace=True)
df0.reset_index(drop=True, inplace=True)
df0
# Out:
#      PassengerId  Survived  Pclass   Sex   Age  SibSp  Parch      Fare  \
# 0              1       0.0       3  Male  22.0      1      0    7.2500
# 1              5       0.0       3  Male  35.0      0      0    8.0500
# 2              6       0.0       3  Male  30.0      0      0    8.4583
# 3              7       0.0       1  Male  54.0      0      0   51.8625
# 4              8       0.0       3  Male   2.0      3      1   21.0750
# ..           ...       ...     ...   ...   ...    ...    ...       ...
# 810         1299       0.0       1  Male  50.0      1      1  211.5000
# 811         1305       0.0       3  Male  30.0      0      0    8.0500
# 812         1307       0.0       3  Male  38.5      0      0    7.2500
# 813         1308       0.0       3  Male  30.0      0      0    8.0500
# 814         1309       0.0       3  Male  30.0      1      1   22.3583
#
#         Embarked
# 0    Southampton
# 1    Southampton
# 2     Queensland
# 3    Southampton
# 4    Southampton
# ...

# %%
plt.figure(figsize=(15,10))
plt.subplot(231)
sb.set(style='whitegrid')
splot = sb.countplot(df0['Sex'],edgecolor=(0,0,0),linewidth=2)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', xytext = (0, 10), textcoords = 'offset points')

plt.subplot(232)
sb.set(style='whitegrid')
splot = sb.countplot(df0['Pclass'],edgecolor=(0,0,0),linewidth=2)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', xytext = (0, 10), textcoords = 'offset points')

plt.subplot(233)
sb.set(style='whitegrid')
splot = sb.countplot(df0['SibSp'],edgecolor=(0,0,0),linewidth=2)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', xytext = (0, 10), textcoords = 'offset points')

plt.subplot(234)
sb.set(style='whitegrid')
splot = sb.countplot(df0['Parch'],edgecolor=(0,0,0),linewidth=2)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', xytext = (0, 10), textcoords = 'offset points')

plt.subplot(235)
sb.set(style='whitegrid')
splot = sb.countplot(df0['Embarked'],edgecolor=(0,0,0),linewidth=2)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', xytext = (0, 10), textcoords = 'offset points')

plt.savefig('count0.jpg')

# %%
df1['Survived'] = df1['Survived'][df['Survived']==1]
df1.dropna(inplace=True)
df1.reset_index(drop=True, inplace=True)
df1
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch      Fare  \
# 0              2       1.0       1  Female  38.0      1      0   71.2833
# 1              3       1.0       3  Female  26.0      0      0    7.9250
# 2              4       1.0       1  Female  35.0      1      0   53.1000
# 3              9       1.0       3  Female  27.0      0      2   11.1333
# 4             10       1.0       2  Female  14.0      1      0   30.0708
# ..           ...       ...     ...     ...   ...    ...    ...       ...
# 489         1301       1.0       3  Female   3.0      1      1   13.7750
# 490         1302       1.0       3  Female  30.0      0      0    7.7500
# 491         1303       1.0       1  Female  37.0      1      0   90.0000
# 492         1304       1.0       3  Female  28.0      0      0    7.7750
# 493         1306       1.0       1  Female  39.0      0      0  108.9000
#
#         Embarked
# 0      Cherbourg
# 1    Southampton
# 2    Southampton
# 3    Southampton
# ...

# %%
plt.figure(figsize=(15,10))
plt.subplot(231)
sb.set(style='whitegrid')
splot = sb.countplot(df1['Sex'],edgecolor=(0,0,0),linewidth=2)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', xytext = (0, 10), textcoords = 'offset points')

plt.subplot(232)
sb.set(style='whitegrid')
splot = sb.countplot(df1['Pclass'],edgecolor=(0,0,0),linewidth=2)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', xytext = (0, 10), textcoords = 'offset points')

plt.subplot(233)
sb.set(style='whitegrid')
splot = sb.countplot(df1['SibSp'],edgecolor=(0,0,0),linewidth=2)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', xytext = (0, 10), textcoords = 'offset points')

plt.subplot(234)
sb.set(style='whitegrid')
splot = sb.countplot(df1['Parch'],edgecolor=(0,0,0),linewidth=2)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', xytext = (0, 10), textcoords = 'offset points')

plt.subplot(235)
sb.set(style='whitegrid')
splot = sb.countplot(df1['Embarked'],edgecolor=(0,0,0),linewidth=2)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', xytext = (0, 10), textcoords = 'offset points')

plt.savefig('count1.jpg')

# %%
sb.FacetGrid(df, col='Survived',size=6).map(plt.hist, 'Age', bins=15, color = 'r')
plt.savefig('countsurv.jpg')
# Out:
# Z:\Anaconda\lib\site-packages\seaborn\axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
